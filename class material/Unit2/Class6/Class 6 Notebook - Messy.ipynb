# %%
import pandas as pd
import numpy as np

# %%
df1 = pd.read_excel('merge1.xlsx')
df2 = pd.read_excel('merge2.xlsx')

# %%
df1
# Out:
#    ID   Name  Age
# 0   1   Jill   23
# 1   2   Jack   45
# 2   3    Jim   21
# 3   4  Janet   47
# 4   5    Joe   87
# 5   6   Jane   21
# 6   7   Jobe   46
# 7   8  Josie   43
# 8   9   Jean   54
# 9  10   Jess   34

# %%
df2
# Out:
#    ID     Name  Gender
# 0   1     Jill  Female
# 1   2     Jack    Male
# 2   3      Jim    Male
# 3   4    Janet  Female
# 4   6     Jane  Female
# 5   7     Jobe    Male
# 6   8    Josie  Female
# 7   9     Jean    Male
# 8  11    Jacob    Male
# 9  12  Jasmine  Female

# %%
df1.merge(df2, on='ID', how='outer')
# Out:
#     ID Name_x   Age   Name_y  Gender
# 0    1   Jill  23.0     Jill  Female
# 1    2   Jack  45.0     Jack    Male
# 2    3    Jim  21.0      Jim    Male
# 3    4  Janet  47.0    Janet  Female
# 4    5    Joe  87.0      NaN     NaN
# 5    6   Jane  21.0     Jane  Female
# 6    7   Jobe  46.0     Jobe    Male
# 7    8  Josie  43.0    Josie  Female
# 8    9   Jean  54.0     Jean    Male
# 9   10   Jess  34.0      NaN     NaN
# 10  11    NaN   NaN    Jacob    Male
# 11  12    NaN   NaN  Jasmine  Female

# %%
pd.concat([df1, df1])
# Out:
#    ID   Name  Age
# 0   1   Jill   23
# 1   2   Jack   45
# 2   3    Jim   21
# 3   4  Janet   47
# 4   5    Joe   87
# 5   6   Jane   21
# 6   7   Jobe   46
# 7   8  Josie   43
# 8   9   Jean   54
# 9  10   Jess   34
# 0   1   Jill   23
# 1   2   Jack   45
# 2   3    Jim   21
# 3   4  Janet   47
# 4   5    Joe   87
# 5   6   Jane   21
# 6   7   Jobe   46
# 7   8  Josie   43
# 8   9   Jean   54
# 9  10   Jess   34

# %%
df = pd.read_csv('titanic.csv')

# %%
df[df['Sex'] == 'female']['Survived'] = 4
# Out:
# 1      1
# 2      1
# 3      1
# 8      1
# 9      1
# 10     1
# 11     1
# 14     0
# 15     1
# 18     0
# 19     1
# 22     1
# 24     0
# 25     1
# 28     1
# 31     1
# 32     1
# 38     0
# 39     1
# 40     0
# 41     0
# 43     1
# 44     1
# 47     1
# 49     0
# 52     1
# 53     1
# 56     1
# 58     1
# 61     1
#       ..
# 807    0
# 809    1
# 813    0
# 816    0
# 820    1
# 823    1
# 829    1
# 830    1
# 835    1
# 842    1
# 849    1
# 852    0
# 853    1
# 854    0
# 855    1
# 856    1
# 858    1
# 862    1
# 863    0
# 865    1
# 866    1
# 871    1
# 874    1
# 875    1
# 879    1
# 880    1
# 882    0
# 885    0
# 887    1
# 888    0
# Name: Survived, Length: 314, dtype: int64

# %%
df.loc[df.Sex == 'female', 'Survived'] = 3

# %%
df['Survived']
# Out:
# 0      0
# 1      3
# 2      3
# 3      3
# 4      0
# 5      0
# 6      0
# 7      0
# 8      3
# 9      3
# 10     3
# 11     3
# 12     0
# 13     0
# 14     3
# 15     3
# 16     0
# 17     1
# 18     3
# 19     3
# 20     0
# 21     1
# 22     3
# 23     1
# 24     3
# 25     3
# 26     0
# 27     0
# 28     3
# 29     0
#       ..
# 861    0
# 862    3
# 863    3
# 864    0
# 865    3
# 866    3
# 867    0
# 868    0
# 869    1
# 870    0
# 871    3
# 872    0
# 873    0
# 874    3
# 875    3
# 876    0
# 877    0
# 878    0
# 879    3
# 880    3
# 881    0
# 882    3
# 883    0
# 884    0
# 885    3
# 886    0
# 887    3
# 888    3
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df2 = df[df.Sex == 'female'].copy()
# Out:
# C:\Users\Jonat\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
# 5      0
# 6      0
# 7      0
# 8      1
# 9      1
# 10     1
# 11     1
# 12     0
# 13     0
# 14     0
# 15     1
# 16     0
# 17     1
# 18     0
# 19     1
# 20     0
# 21     1
# 22     1
# 23     1
# 24     0
# 25     1
# 26     0
# 27     0
# 28     1
# 29     0
#       ..
# 861    0
# 862    1
# 863    0
# 864    0
# 865    1
# 866    1
# 867    0
# 868    0
# 869    1
# 870    0
# 871    1
# 872    0
# 873    0
# 874    1
# 875    1
# 876    0
# 877    0
# 878    0
# 879    1
# 880    1
# 881    0
# 882    0
# 883    0
# 884    0
# 885    0
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
df.isnull().sum() > 0
# Out:
# PassengerId    False
# Survived       False
# Pclass         False
# Name           False
# Sex            False
# Age             True
# SibSp          False
# Parch          False
# Ticket         False
# Fare           False
# Cabin           True
# Embarked        True
# dtype: bool

# %%
df.loc[:, df.isnull().sum() > 0]
# Out:
#       Age        Cabin Embarked
# 0    22.0          NaN        S
# 1    38.0          C85        C
# 2    26.0          NaN        S
# 3    35.0         C123        S
# 4    35.0          NaN        S
# 5     NaN          NaN        Q
# 6    54.0          E46        S
# 7     2.0          NaN        S
# 8    27.0          NaN        S
# 9    14.0          NaN        C
# 10    4.0           G6        S
# 11   58.0         C103        S
# 12   20.0          NaN        S
# 13   39.0          NaN        S
# 14   14.0          NaN        S
# 15   55.0          NaN        S
# 16    2.0          NaN        Q
# 17    NaN          NaN        S
# 18   31.0          NaN        S
# 19    NaN          NaN        C
# 20   35.0          NaN        S
# 21   34.0          D56        S
# 22   15.0          NaN        Q
# 23   28.0           A6        S
# 24    8.0          NaN        S
# 25   38.0          NaN        S
# 26    NaN          NaN        C
# 27   19.0  C23 C25 C27        S
# ...

# %%
df['Age'] > 35
# Out:
# 0      False
# 1       True
# 2      False
# 3      False
# 4      False
# 5      False
# 6       True
# 7      False
# 8      False
# 9      False
# 10     False
# 11      True
# 12     False
# 13      True
# 14     False
# 15      True
# 16     False
# 17     False
# 18     False
# 19     False
# 20     False
# 21     False
# 22     False
# 23     False
# 24     False
# 25      True
# 26     False
# 27     False
# 28     False
# 29     False
#        ...
# 861    False
# 862     True
# 863    False
# 864    False
# 865     True
# 866    False
# 867    False
# 868    False
# 869    False
# 870    False
# 871     True
# 872    False
# 873     True
# 874    False
# 875    False
# 876    False
# 877    False
# 878    False
# 879     True
# 880    False
# 881    False
# 882    False
# 883    False
# 884    False
# 885     True
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Age, Length: 891, dtype: bool

# %%
num_cols = df.select_dtypes(include=np.number).columns.tolist()

# %%
df[num_cols] = df[num_cols].fillna(df[num_cols].mean())

# %%
df['Age'].describe()
# Out:
# count    891.000000
# mean      29.699118
# std       13.002015
# min        0.420000
# 25%       22.000000
# 50%       29.699118
# 75%       35.000000
# max       80.000000
# Name: Age, dtype: float64

# %%
rock = pd.read_csv('rock.csv')

# %%
rock.head()
# Out:
#                Song Clean ARTIST CLEAN Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special          NaN
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
rock.loc[rock['Release Year'].isnull(), 'Release Year'] = 0

# %%
rock = rock.rename({'ARTIST CLEAN': 'Artist'}, axis=1)

# %%
pd.read_csv('rock.csv', names={})
# Out:
#                Song Clean       Artist Release Year  \
# 0        Caught Up in You  .38 Special         1982
# 1            Fantasy Girl  .38 Special            0
# 2         Hold On Loosely  .38 Special         1981
# 3  Rockin' Into the Night  .38 Special         1980
# 4       Art For Arts Sake         10cc         1975
#
#                                 COMBINED  First?  Year?  PlayCount  F*G
# 0        Caught Up in You by .38 Special       1      1         82   82
# 1            Fantasy Girl by .38 Special       1      0          3    0
# 2         Hold On Loosely by .38 Special       1      1         85   85
# 3  Rockin' Into the Night by .38 Special       1      1         18   18
# 4              Art For Arts Sake by 10cc       1      1          1    1

# %%
new_cols = [col.lower() for col in rock.columns.tolist()]

# %%
new_cols
# Out:
# ['song clean',
#  'artist',
#  'release year',
#  'combined',
#  'first?',
#  'year?',
#  'playcount',
#  'f*g']

# %%
rock.columns = new_cols

# %%
rock.dtypes
# Out:
# song clean      object
# artist          object
# release year    object
# combined        object
# first?           int64
# year?            int64
# playcount        int64
# f*g              int64
# dtype: object

# %%
rock['release year'].unique()
# Out:
# array(['1982', 0, '1981', '1980', '1975', '2000', '2002', '1992', '1985',
#        '1993', '1976', '1995', '1979', '1984', '1977', '1990', '1986',
#        '1974', '2014', '1987', '1973', '2001', '1989', '1997', '1971',
#        '1972', '1994', '1970', '1966', '1965', '1983', '1955', '1978',
#        '1969', '1999', '1968', '1988', '1962', '2007', '1967', '1958',
#        '1071', '1996', '1991', '2005', '2011', '2004', '2012', '2003',
#        '1998', '2008', '1964', '2013', '2006', 'SONGFACTS.COM', '1963',
#        '1961'], dtype=object)

# %%
rock['release year'] = rock['release year'].astype(str)

# %%
rock[~rock['release year'].str.isdigit()]
# Out:
#           song clean          artist   release year  \
# 1504  Bullfrog Blues  Rory Gallagher  SONGFACTS.COM
#
#                               combined  first?  year?  playcount  f*g
# 1504  Bullfrog Blues by Rory Gallagher       1      1          1    1

# %%
rock.loc[rock['release year'] == 'SONGFACTS.COM', 'release year'] = 0

# %%
rock['release year'] = rock['release year'].astype(np.int)

# %%
not True
# Out:
# False

# %%
rock.columns
# Out:
# Index(['song clean', 'artist', 'release year', 'combined', 'first?', 'year?',
#        'playcount', 'f*g'],
#       dtype='object')

# %%
def get_vals(row):
    print(row['song clean'], row['artist'], row['release year'], '< 1970?:', row['release year'] < 1970)

# %%
rock.head(5).apply(get_vals, axis=1)
# Out:
# Caught Up in You .38 Special 1982 < 1970?: False
# Fantasy Girl .38 Special 0 < 1970?: True
# Hold On Loosely .38 Special 1981 < 1970?: False
# Rockin' Into the Night .38 Special 1980 < 1970?: False
# Art For Arts Sake 10cc 1975 < 1970?: False
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %%
rock['release year'] = rock['release year'].astype(np.int)

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df.groupby('Pclass').sum()
# Out:
#         PassengerId  Survived      Age  SibSp  Parch        Fare
# Pclass
# 1             99705       136  7111.42     90     77  18177.4125
# 2             82056        87  5168.83     74     70   3801.8417
# 3            215625       119  8924.92    302    193   6714.6951

# %%
df[df['Embarked'] == 'Q'].groupby(['Sex', 'Pclass'])['Age'].agg(['mean', 'sum'])
# Out:
#                     mean    sum
# Sex    Pclass
# female 1       33.000000   33.0
#        2       30.000000   30.0
#        3       22.850000  228.5
# male   1       44.000000   44.0
#        2       57.000000   57.0
#        3       28.142857  394.0

# %%
type(df[['Age', 'Fare']])
# Out:
# pandas.core.frame.DataFrame

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 0499-EE93
#
#  Directory of C:\Users\Jonat\ga\DAT-10-14\class material\Unit2\data
#
# 10/30/2019  02:06 PM    <DIR>          .
# 10/30/2019  02:06 PM    <DIR>          ..
# 10/28/2019  03:21 PM             8,925 merge1.xlsx
# 10/28/2019  03:19 PM             8,904 merge2.xlsx
# 06/26/2019  10:53 AM           167,189 rock.csv
# 04/19/2018  02:10 PM         3,364,352 superstore.xls
# 01/09/2019  11:55 PM            61,194 titanic.csv
# 06/26/2019  10:53 AM            23,611 user.tbl
#                6 File(s)      3,634,175 bytes
#                2 Dir(s)  838,496,002,048 bytes free

# %%
sales = pd.read_excel('superstore.xls')

# %%
sales.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City    ...     \
# 0      Claire Gute   Consumer  United States        Henderson    ...
# 1      Claire Gute   Consumer  United States        Henderson    ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles    ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale    ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
sales = sales.set_index('Order Date')

# %%
sales.head()
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2016-11-08      Claire Gute   Consumer  United States        Henderson
# 2016-11-08      Claire Gute   Consumer  United States        Henderson
# 2016-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2015-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2015-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
sales.groupby('Category').resample('M')['Sales'].sum()
# Out:
# Category    Order Date
# Furniture   2014-01-31     6242.5250
#             2014-02-28     1839.6580
#             2014-03-31    14573.9560
#             2014-04-30     7944.8370
#             2014-05-31     6912.7870
#             2014-06-30    13206.1256
#             2014-07-31    10821.0510
#             2014-08-31     7320.3465
#             2014-09-30    23816.4808
#             2014-10-31    12304.2470
#             2014-11-30    21564.8727
#             2014-12-31    30645.9665
#             2015-01-31    11739.9416
#             2015-02-28     3134.3740
#             2015-03-31    12499.7830
#             2015-04-30    10475.6985
#             2015-05-31     9374.9505
#             2015-06-30     7714.1790
#             2015-07-31    13674.4200
#             2015-08-31     9638.5922
#             2015-09-30    26273.0230
#             2015-10-31    12026.6235
#             2015-11-30    30880.8325
#             2015-12-31    23085.8192
#             2016-01-31     7622.7430
# ...

# %%
sales.head()
# Out:
#             Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# Order Date
# 2016-11-08       1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-11-08       2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2016-06-12       3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 2015-10-11       4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 2015-10-11       5  US-2015-108966 2015-10-18  Standard Class    SO-20335
#
#               Customer Name    Segment        Country             City  \
# Order Date
# 2016-11-08      Claire Gute   Consumer  United States        Henderson
# 2016-11-08      Claire Gute   Consumer  United States        Henderson
# 2016-06-12  Darrin Van Huff  Corporate  United States      Los Angeles
# 2015-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
# 2015-10-11   Sean O'Donnell   Consumer  United States  Fort Lauderdale
#
# ...

# %%
grouped = sales.groupby('Category')['Sales'].mean().to_frame().rename({'Sales': 'Cat Avg'}, axis=1)

# %%
grouped
# Out:
#                       Sales
# Category
# Furniture        349.834887
# Office Supplies  119.324101
# Technology       452.709276

# %%
sales.merge(grouped, on='Category', how='left')
# Out:
#       Row ID        Order ID  Ship Date       Ship Mode Customer ID  \
# 0          1  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 1          2  CA-2016-152156 2016-11-11    Second Class    CG-12520
# 2          3  CA-2016-138688 2016-06-16    Second Class    DV-13045
# 3          4  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 4          5  US-2015-108966 2015-10-18  Standard Class    SO-20335
# 5          6  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 6          7  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 7          8  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 8          9  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 9         10  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 10        11  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 11        12  CA-2014-115812 2014-06-14  Standard Class    BH-11710
# 12        13  CA-2017-114412 2017-04-20  Standard Class    AA-10480
# ...

# %%
three_mo_offset = pd.DateOffset(months=3)

# %%
sales.groupby('Customer Name')['Ship Date'].min() + three_mo_offset
# Out:
# Customer Name
# Aaron Bergman          2014-05-24
# Aaron Hawkins          2014-07-24
# Aaron Smayling         2014-11-02
# Adam Bellavance        2015-12-24
# Adam Hart              2015-02-22
# Adam Shillingsburg     2014-12-29
# Adrian Barton          2015-03-23
# Adrian Hane            2014-10-18
# Adrian Shami           2017-02-19
# Aimee Bixby            2014-06-08
# Alan Barnes            2015-02-20
# Alan Dominguez         2015-02-22
# Alan Haines            2015-06-07
# Alan Hwang             2015-03-06
# Alan Schoenberger      2015-01-20
# Alan Shonely           2014-06-19
# Alejandro Ballentine   2014-10-28
# Alejandro Grove        2014-08-15
# Alejandro Savely       2016-08-26
# Aleksandra Gannaway    2014-08-03
# Alex Avila             2014-07-05
# Alex Grayson           2016-11-05
# Alex Russell           2015-04-03
# Alice McCarthy         2015-01-08
# Allen Armold           2014-07-25
# Allen Goldenen         2014-07-23
# Allen Rosenblatt       2015-01-08
# ...

# %%
new_df = pd.DataFrame()

new_df['Customer Name'] = sales['Customer Name'].unique()

# %%
grouped = sales.groupby('Customer Name')['Sales'].sum().to_frame()

# %%
grouped = grouped.reset_index()

# %%
new_df
# Out:
#                   Names
# 0           Claire Gute
# 1       Darrin Van Huff
# 2        Sean O'Donnell
# 3       Brosina Hoffman
# 4          Andrew Allen
# 5          Irene Maddox
# 6         Harold Pawlan
# 7             Pete Kriz
# 8       Alejandro Grove
# 9    Zuschuss Donatelli
# 10            Ken Black
# 11      Sandra Flanagan
# 12          Emily Burns
# 13        Eric Hoffmann
# 14      Tracy Blumstein
# 15         Matt Abelman
# 16            Gene Hale
# 17         Steve Nguyen
# 18       Linda Cazamias
# 19         Ruben Ausman
# 20           Erin Smith
# 21        Odella Nelson
# 22    Patrick O'Donnell
# 23       Lena Hernandez
# 24        Darren Powers
# 25       Janet Molinari
# 26      Ted Butterfield
# 27         Kunst Miller
# 28       Paul Stevenson
# 29        Brendan Sweed
# ..                  ...
# 763      Frank Carlisle
# 764       Thea Hudgings
# 765       Juliana Krohn
# 766         Sarah Brown
# 767      Barry Gonzalez
# 768       Barry Weirich
# ...

# %%
new_df.merge(grouped, on='Customer Name', how='left')
# Out:
#           Customer Name      Sales
# 0           Claire Gute  1148.7800
# 1       Darrin Van Huff  1119.4830
# 2        Sean O'Donnell  2602.5755
# 3       Brosina Hoffman  6255.3510
# 4          Andrew Allen  1790.5120
# 5          Irene Maddox  4930.4740
# 6         Harold Pawlan  1990.3140
# 7             Pete Kriz  8646.9340
# 8       Alejandro Grove  2582.8980
# 9    Zuschuss Donatelli  1493.9440
# 10            Ken Black  2744.7420
# 11      Sandra Flanagan   763.5460
# 12          Emily Burns  2767.2190
# 13        Eric Hoffmann   684.1710
# 14      Tracy Blumstein  4737.4860
# 15         Matt Abelman  4299.1610
# 16            Gene Hale  1361.2440
# 17         Steve Nguyen  3127.9592
# 18       Linda Cazamias  4492.9460
# 19         Ruben Ausman  3832.3140
# 20           Erin Smith  4657.9240
# 21        Odella Nelson  1567.5200
# 22    Patrick O'Donnell  2493.2140
# 23       Lena Hernandez  2295.3320
# 24        Darren Powers  1050.6360
# 25       Janet Molinari  1804.1460
# ...

# %%
grouped
# Out:
#                           Sales
# Customer Name
# Aaron Bergman           886.156
# Aaron Hawkins          1744.700
# Aaron Smayling         3050.692
# Adam Bellavance        7755.620
# Adam Hart              3250.337
# Adam Shillingsburg     3255.310
# Adrian Barton         14473.571
# Adrian Hane            1735.514
# Adrian Shami             58.820
# Aimee Bixby             966.710
# Alan Barnes            1113.838
# Alan Dominguez         6106.880
# Alan Haines            1587.452
# Alan Hwang             4805.344
# Alan Schoenberger      4260.784
# Alan Shonely            584.608
# Alejandro Ballentine    914.532
# Alejandro Grove        2582.898
# Alejandro Savely       3214.236
# Aleksandra Gannaway     367.548
# Alex Avila             5563.560
# Alex Grayson            660.972
# Alex Russell           1055.694
# Alice McCarthy          814.012
# Allen Armold           1056.390
# Allen Goldenen          200.945
# Allen Rosenblatt       2236.128
# ...

# %%
new_df
# Out:
#                   Names
# 0           Claire Gute
# 1       Darrin Van Huff
# 2        Sean O'Donnell
# 3       Brosina Hoffman
# 4          Andrew Allen
# 5          Irene Maddox
# 6         Harold Pawlan
# 7             Pete Kriz
# 8       Alejandro Grove
# 9    Zuschuss Donatelli
# 10            Ken Black
# 11      Sandra Flanagan
# 12          Emily Burns
# 13        Eric Hoffmann
# 14      Tracy Blumstein
# 15         Matt Abelman
# 16            Gene Hale
# 17         Steve Nguyen
# 18       Linda Cazamias
# 19         Ruben Ausman
# 20           Erin Smith
# 21        Odella Nelson
# 22    Patrick O'Donnell
# 23       Lena Hernandez
# 24        Darren Powers
# 25       Janet Molinari
# 26      Ted Butterfield
# 27         Kunst Miller
# 28       Paul Stevenson
# 29        Brendan Sweed
# ..                  ...
# 763      Frank Carlisle
# 764       Thea Hudgings
# 765       Juliana Krohn
# 766         Sarah Brown
# 767      Barry Gonzalez
# 768       Barry Weirich
# ...

# %%
sales.groupby('M')['Sales'].sum()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-175-a2710b18a271> in <module>
# ----> 1 sales.groupby('M')['Sales'].sum()
#
# ~\Anaconda\lib\site-packages\pandas\core\generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, **kwargs)
#    6663         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    6664                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 6665                        observed=observed, **kwargs)
#    6666
#    6667     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# ~\Anaconda\lib\site-packages\pandas\core\groupby\groupby.py in groupby(obj, by, **kwds)
#    2150         raise TypeError('invalid type: %s' % type(obj))
#    2151
# -> 2152     return klass(obj, by, **kwds)
#    2153
#    2154
#
# ...

# %%
sales.index
# Out:
# DatetimeIndex(['2016-11-08', '2016-11-08', '2016-06-12', '2015-10-11',
#                '2015-10-11', '2014-06-09', '2014-06-09', '2014-06-09',
#                '2014-06-09', '2014-06-09',
#                ...
#                '2015-05-17', '2015-05-17', '2016-09-29', '2017-11-17',
#                '2017-11-17', '2014-01-21', '2017-02-26', '2017-02-26',
#                '2017-02-26', '2017-05-04'],
#               dtype='datetime64[ns]', name='Order Date', length=9994, freq=None)

# %%
sales.resample('D')['Sales'].sum()
# Out:
# Order Date
# 2014-01-03      16.4480
# 2014-01-04     288.0600
# 2014-01-05      19.5360
# 2014-01-06    4407.1000
# 2014-01-07      87.1580
# 2014-01-08       0.0000
# 2014-01-09      40.5440
# 2014-01-10      54.8300
# 2014-01-11       9.9400
# 2014-01-12       0.0000
# 2014-01-13    3553.7950
# 2014-01-14      61.9600
# 2014-01-15     149.9500
# 2014-01-16     299.9640
# 2014-01-17       0.0000
# 2014-01-18      64.8640
# 2014-01-19     378.5940
# 2014-01-20    2673.8700
# 2014-01-21      25.2480
# 2014-01-22       0.0000
# 2014-01-23      46.0200
# 2014-01-24       0.0000
# 2014-01-25       0.0000
# 2014-01-26    1097.2500
# 2014-01-27     426.6700
# 2014-01-28       3.9280
# 2014-01-29       0.0000
# 2014-01-30     240.5000
# 2014-01-31     290.6660
# 2014-02-01     468.9000
#                 ...
# 2017-12-01    5331.1780
# 2017-12-02    9951.1820
# 2017-12-03    1403.8420
# 2017-12-04    2639.6380
# 2017-12-05    1453.1360
# 2017-12-06      10.6800
# 2017-12-07    2916.5140
# ...
